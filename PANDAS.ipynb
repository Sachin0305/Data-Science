# %% [markdown]
# # Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as pd

# %%
S=pd.Series([4,8,15,16,23,42])

# %%
S
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %% [markdown]
# # Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the variable print it.

# %%
list1=[1,2,4,"happy","sad",4,2,1,"Excited","Zero"]

# %%
pd.Series(list1)
# Out:
# 0          1
# 1          2
# 2          4
# 3      happy
# 4        sad
# 5          4
# 6          2
# 7          1
# 8    Excited
# 9       Zero
# dtype: object

# %%
pd.DataFrame(list1)
# Out:
#          0
# 0        1
# 1        2
# 2        4
# 3    happy
# 4      sad
# 5        4
# 6        2
# 7        1
# 8  Excited
# 9     Zero

# %% [markdown]
# # Q3. Create a Pandas DataFrame that contains the following data
# ![Data%20Table.jpg](attachment:Data%20Table.jpg)
# Then, print the DataFrame.

# %%
data={'Name':['Alice','Bob','Claire'],'Age':[25,30,27],'Gender':['Female','Male','Female']}

# %%
 frame=pd.DataFrame(data)

# %%
frame
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %%
for index, row in frame.iterrows():

    print(row['Name'], row['Age'])
# Out:
# Alice 25
# Bob 30
# Claire 27

# %%
df_reindex=frame.reindex([2,1,0])

# %%
df_reindex
# Out:
#      Name  Age  Gender
# 2  Claire   27  Female
# 1     Bob   30    Male
# 0   Alice   25  Female

# %% [markdown]
# # Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.

# %% [markdown]
# ## DATA FRAME

# %% [markdown]
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
data2 = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object
df=pd.DataFrame(data2)

df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ## SERIES

# %% [markdown]
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
d = [1, 7, 2]

S= pd.Series(d)

S
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# # Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?

# %% [markdown]
# ### There are many functions to manipulate data in a Pandas DataFrame.

# %% [markdown]
# 10 of them are:
#
# 1.Head & Tail
#
# 2.DataFrame.info()
#
# 3.Dtypes()
#
# 4.Shape & Size
#
# 5.describe()
#
# 6.Sample()
#
# 7.Identifying missing values isnull()
#
# 8.isna()
#
# 9.Nunique()
#
# 10.index & column

# %%
Service=pd.read_csv("Services.csv")

# %%
Service
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
type(Service)
# Out:
# pandas.core.frame.DataFrame

# %%
Service.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
Service.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
 Service.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %% [markdown]
# # Q6. Which of the following is mutable in nature Series, DataFrame, Panel?

# %% [markdown]
# ### Data Frame & Panel is mutuable in nature.

# %% [markdown]
# # Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
Name=pd.Series(["Sachin","Rohan","Rohit"])
Company=pd.Series(["HCL","TCS","INFOSYS"])
College=pd.Series(["Miet","Diet","Riet"])

# %%
Details=pd.concat([Name,Company,College],axis=1)

# %%
Details
# Out:
#         0        1     2
# 0  Sachin      HCL  Miet
# 1   Rohan      TCS  Diet
# 2   Rohit  INFOSYS  Riet

# %%
type(Details)
# Out:
# pandas.core.frame.DataFrame
